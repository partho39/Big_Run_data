# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('rundata.csv')
data.shape
print("Data row :-", data.shape[0])
print("Data coloums :-", data.shape[1])
# Out:
# C:\Users\Partho Sarker\AppData\Local\Temp\ipykernel_6708\1329220186.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('rundata.csv')
# Data row :- 7461195
# Data coloums :- 13

# %%
data.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
filtered_data = data[
    (data['Event distance/length'].isin(['50km', '50mi'])) &
    (data['Year of event'] == 2020) &
    (data['Event name'].str.extract(r'\((.*?)\)')[0] == 'USA')
]

filtered_data
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
filtered_data.head(10)
filtered_data.shape
# Out:
# (26090, 13)

# %%
#Remove USA from Event Name

filtered_data['Event name'] =filtered_data['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\Partho Sarker\AppData\Local\Temp\ipykernel_6708\272467740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Event name'] =filtered_data['Event name'].str.split('(').str.get(0)

# %%
filtered_data.head(1)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
#
#                Athlete club Athlete country  Athlete year of birth  \
# 2539945  *Normandy Park, WA             USA                 1991.0
#
#         Athlete gender  Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  29.0                15.158       71287

# %%
#Clean up Athlete age
filtered_data['Athlete age category']= 2020 - filtered_data['Athlete year of birth']
# Out:
# C:\Users\Partho Sarker\AppData\Local\Temp\ipykernel_6708\3097775301.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Athlete age category']= 2020 - filtered_data['Athlete year of birth']

# %%
# Remove h in Athlete performance
filtered_data['Athlete performance'] = filtered_data['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Partho Sarker\AppData\Local\Temp\ipykernel_6708\154779947.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Athlete performance'] = filtered_data['Athlete performance'].str.split(' ').str.get(0)

# %%
filtered_data.head(1)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
#
#                Athlete club Athlete country  Athlete year of birth  \
# 2539945  *Normandy Park, WA             USA                 1991.0
#
#         Athlete gender  Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  29.0                15.158       71287
